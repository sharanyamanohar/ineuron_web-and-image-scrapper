# %%
from flask import Flask,render_template,request,jsonify

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
#from the flipkart url adding the products to search
flipkart_url="https://www.flipkart.com/search?q="+"iphone11"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
#giving the request
urReq(flipkart_url)

# %%
response_website=urReq(flipkart_url)

# %%
data_flipkart=response_website.read()

# %%
#which beatufies the regular data
beautifyed_html=bs(data_flipkart,"html.parser")

# %%
bigbox=beautifyed_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
len(beautifyed_html.find_all("div",{"class":"_1AtVbE col-12-12"}))
# Out:
# 29

# %%
bigbox[6].div.div
# Out:
# <div data-id="MOBFWQ6BEHFXGXGB" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-11-purple-128-gb/p/itmb7ca0b05522ff?pid=MOBFWQ6BEHFXGXGB&amp;lid=LSTMOBFWQ6BEHFXGXGBMVHGLV&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_5&amp;otracker=search&amp;fm=organic&amp;iid=5461dc1e-c03b-486b-8f46-f876f33c5436.MOBFWQ6BEHFXGXGB.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=qcya9h5fpc0000001661594792732&amp;qH=d6db477051465f9a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 11 (Purple, 128 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/y/k/z/iphone-11-64-a-mwlx2hn-a-apple-0-original-imafkg24ymsjav9h.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><
# ...

# %%
"https://www.flipkart.com" + bigbox[6].div.div.a['href']
# Out:
# 'https://www.flipkart.com/apple-iphone-11-purple-128-gb/p/itmb7ca0b05522ff?pid=MOBFWQ6BEHFXGXGB&lid=LSTMOBFWQ6BEHFXGXGBMVHGLV&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=5461dc1e-c03b-486b-8f46-f876f33c5436.MOBFWQ6BEHFXGXGB.SEARCH&ppt=None&ppn=None&ssid=qcya9h5fpc0000001661594792732&qH=d6db477051465f9a'

# %%
import requests

# %%
product6="https://www.flipkart.com" + bigbox[6].div.div.a['href']
product66=requests.get(product6)
product66
# Out:
# <Response [200]>

# %%
product66.encoding='utf-8'

# %%
product6_page=bs(product66.text,"html.parser")

# %%
product6_page.find_all('div',{"class":"_16PBlm"})
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202011/blobio-imr-202011_e4b34b9e355e4836ade8b1f6345ee73b.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Flipkart Customer</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path 
# ...

# %%
all_review=product6_page.find_all('div',{"class":"_16PBlm"})

# %%
review=all_review[5].div.div.div.div.text

# %%
len(all_review)
# Out:
# 11

# %%
all_review[5].div.find_all('div' , {'class' : ""})[0].div.text
# Out:
# 'This is my first iOS phone. I am very happy with this product. Very much satisfied with this. I love this phone.'

# %%
rating = all_review[5].div.div.div.div.text

# %%
rating
# Out:
# '5'

# %%
name  = all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
comment_header = all_review[5].div.div.div.p.text

# %%
comment_header
# Out:
# 'Fabulous!'

# %%
all_review[5].div.find_all('p' , {"class":"_2sc7ZR"})[1].text
# Out:
# 'Mar, 2020'

# %%
all_review
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202011/blobio-imr-202011_e4b34b9e355e4836ade8b1f6345ee73b.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Flipkart Customer</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path 
# ...

# %%
product6_page.find_all('div' , {"class":"_30jeq3 _16Jk6d"})[0].text
# Out:
# '₹54,900'

# %%
for i in all_review:
    price = product6_page.find_all('div' , {"class":"_30jeq3 _16Jk6d"})[0].text
    long_review = i.div.find_all('p' , {"class":"_2sc7ZR"})[1].text
    comment_header = i.div.div.div.p.text
    name  = i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
    rating = i.div.div.div.div.text
    long = i.div.find_all('div' , {'class' : ""})[0].div.text
    print(name, rating, comment_header,long_review,price,long )
    print()
# Out:
# Flipkart Customer 5 Simply awesome Nov, 2020 ₹54,900 Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.
#
# Flipkart Customer 5 Perfect product! Jun, 2020 ₹54,900 Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .
#
# Manish Raghuvanshi 5 Best in the market! Apr, 2021 ₹54,900 Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7. Pros-Camera top class - Battery top performed -Chipset no need to say as apple kind -Security as you expect from apple - Display super bright industry leading colour   accuracy and super responsive -Build quality as expect from apple sturdy  premium durable beautiful stylish. -Os most stable os in smartphone industry Cons -No 5G-Display is not based on OLED technology -Charger headphones and 1 apple stic...
#
# ...
